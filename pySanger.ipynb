# %%
import sys
sys.path.append('/Users/mayongzhi/Desktop/bioinformatic_project/genotyping_tool/PySanger')
import os
from pysanger import *
import matplotlib.pyplot as plt

# %%
def visualize_sanger_sequences(file_path, template, highlight_positions):
    # Extract filename without extension for saving figures
    base_name = os.path.basename(file_path).split('.')[0]

    # Read ABI data
    abidata = abi_to_dict(filename=file_path)
    
    # Generate consensus sequences (if needed)
    f_seq, r_seq = generate_consensusseq(abidata)
    
    # Visualize the Sanger sequences
    fig = visualize(abidata, template = template, region = "aligned", highlight_positions = highlight_positions)
    plt.title(base_name)

    # Save the figure
    fig.savefig(f"{base_name}.png", bbox_inches = 'tight')
    #plt.close(fig)  # Close the figure to free memory

# %%
visualize_sanger_sequences("/Users/mayongzhi/Desktop/bioinformatic_project/genotyping_tool/F38_otof-Rprimer.ab1", "ATGCCGTGTCAGGCCGGCTA", [4,10,14])
# Out:
# /var/folders/5l/znh6jbkd5bd5t6h2lh80j_3r0000gn/T/ipykernel_8058/2046309554.py:15: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
test1_file_path = '/Users/mayongzhi/Desktop/聽損lab/定序/otof/SD240416039__240416M13B'
test2_file_path = '/Users/mayongzhi/Desktop/聽損lab/定序/otof/64-8_17-1130328-1_2024-03-28'
template = 'ATGCCGTGTCAGGCCGGCTA'
highlight_positions = [4,10,14]

# %%
def multiple_pysanger_plot(file_path, template, highlight_positions):
    for f in os.listdir(file_path):
        if f.endswith('.ab1'):
            complete_file_path = os.path.join(file_path,f)
            visualize_sanger_sequences(complete_file_path, template, highlight_positions)

# %%
multiple_pysanger_plot(test1_file_path, template, highlight_positions)
# Out:
# /var/folders/5l/znh6jbkd5bd5t6h2lh80j_3r0000gn/T/ipykernel_8058/2046309554.py:15: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /var/folders/5l/znh6jbkd5bd5t6h2lh80j_3r0000gn/T/ipykernel_8058/2046309554.py:15: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
multiple_pysanger_plot(test2_file_path, template, highlight_positions)
# Out:
# /var/folders/5l/znh6jbkd5bd5t6h2lh80j_3r0000gn/T/ipykernel_8058/2046309554.py:15: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /var/folders/5l/znh6jbkd5bd5t6h2lh80j_3r0000gn/T/ipykernel_8058/2046309554.py:15: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /var/folders/5l/znh6jbkd5bd5t6h2lh80j_3r0000gn/T/ipykernel_8058/2046309554.py:15: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /var/folders/5l/znh6jbkd5bd5t6h2lh80j_3r0000gn/T/ipykernel_8058/2046309554.py:15: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /var/folders/5l/znh6jbkd5bd5t6h2lh80j_3r0000gn/T/ipykernel_8058/2046309554.py:15: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /var/folders/5l/znh6jbkd5bd5t6h2lh80j_3r0000gn/T/ipykernel_8058/2046309554.py:15: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /var/folders/5l/znh6jbkd5bd5t6h2lh80j_3r0000gn/T/ipykernel_8058/2046309554.py:15: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /var/folders/5l/znh6jbkd5bd5t6h2lh80j_3r0000gn/T/ipykernel_8058/2046309554.py:15: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /var/folders/5l/znh6jbkd5bd5t6h2lh80j_3r0000gn/T/ipykernel_8058/2046309554.py:15: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /var/folders/5l/znh6jbkd5bd5t6h2lh80j_3r0000gn/T/ipykernel_8058/2046309554.py:15: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
new_path = "/Users/mayongzhi/Desktop/聽損lab/定序/otof/1130808-1_2024-08-08/"
multiple_pysanger_plot(new_path, template, highlight_positions)
# Out:
# /var/folders/5l/znh6jbkd5bd5t6h2lh80j_3r0000gn/T/ipykernel_8058/2046309554.py:15: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /var/folders/5l/znh6jbkd5bd5t6h2lh80j_3r0000gn/T/ipykernel_8058/2046309554.py:15: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /var/folders/5l/znh6jbkd5bd5t6h2lh80j_3r0000gn/T/ipykernel_8058/2046309554.py:15: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /var/folders/5l/znh6jbkd5bd5t6h2lh80j_3r0000gn/T/ipykernel_8058/2046309554.py:15: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /var/folders/5l/znh6jbkd5bd5t6h2lh80j_3r0000gn/T/ipykernel_8058/2046309554.py:15: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /var/folders/5l/znh6jbkd5bd5t6h2lh80j_3r0000gn/T/ipykernel_8058/2046309554.py:15: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /var/folders/5l/znh6jbkd5bd5t6h2lh80j_3r0000gn/T/ipykernel_8058/2046309554.py:15: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /var/folders/5l/znh6jbkd5bd5t6h2lh80j_3r0000gn/T/ipykernel_8058/2046309554.py:15: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /var/folders/5l/znh6jbkd5bd5t6h2lh80j_3r0000gn/T/ipykernel_8058/2046309554.py:15: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /var/folders/5l/znh6jbkd5bd5t6h2lh80j_3r0000gn/T/ipykernel_8058/2046309554.py:15: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /var/folders/5l/znh6jbkd5bd5t6h2lh80j_3r0000gn/T/ipykernel_8058/2046309554.py:15: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /var/folders/5l/znh6jbkd5bd5t6h2lh80j_3r0000gn/T/ipykernel_8058/2046309554.py:15: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /var/folders/5l/znh6jbkd5bd5t6h2lh80j_3r0000gn/T/ipykernel_8058/2046309554.py:15: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /var/folders/5l/znh6jbkd5bd5t6h2lh80j_3r0000gn/T/ipykernel_8058/2046309554.py:15: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /var/folders/5l/znh6jbkd5bd5t6h2lh80j_3r0000gn/T/ipykernel_8058/2046309554.py:15: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /var/folders/5l/znh6jbkd5bd5t6h2lh80j_3r0000gn/T/ipykernel_8058/2046309554.py:15: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /var/folders/5l/znh6jbkd5bd5t6h2lh80j_3r0000gn/T/ipykernel_8058/2046309554.py:15: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /var/folders/5l/znh6jbkd5bd5t6h2lh80j_3r0000gn/T/ipykernel_8058/2046309554.py:15: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /var/folders/5l/znh6jbkd5bd5t6h2lh80j_3r0000gn/T/ipykernel_8058/2046309554.py:15: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /var/folders/5l/znh6jbkd5bd5t6h2lh80j_3r0000gn/T/ipykernel_8058/2046309554.py:15: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /Users/mayongzhi/Desktop/bioinformatic_project/genotyping_tool/PySanger/pysanger.py:277: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig = plt.figure(figsize=(3,3))
# /var/folders/5l/znh6jbkd5bd5t6h2lh80j_3r0000gn/T/ipykernel_8058/2046309554.py:15: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /var/folders/5l/znh6jbkd5bd5t6h2lh80j_3r0000gn/T/ipykernel_8058/2046309554.py:15: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /var/folders/5l/znh6jbkd5bd5t6h2lh80j_3r0000gn/T/ipykernel_8058/2046309554.py:15: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /var/folders/5l/znh6jbkd5bd5t6h2lh80j_3r0000gn/T/ipykernel_8058/2046309554.py:15: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /var/folders/5l/znh6jbkd5bd5t6h2lh80j_3r0000gn/T/ipykernel_8058/2046309554.py:15: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /var/folders/5l/znh6jbkd5bd5t6h2lh80j_3r0000gn/T/ipykernel_8058/2046309554.py:15: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /var/folders/5l/znh6jbkd5bd5t6h2lh80j_3r0000gn/T/ipykernel_8058/2046309554.py:15: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /var/folders/5l/znh6jbkd5bd5t6h2lh80j_3r0000gn/T/ipykernel_8058/2046309554.py:15: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /var/folders/5l/znh6jbkd5bd5t6h2lh80j_3r0000gn/T/ipykernel_8058/2046309554.py:15: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /var/folders/5l/znh6jbkd5bd5t6h2lh80j_3r0000gn/T/ipykernel_8058/2046309554.py:15: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /var/folders/5l/znh6jbkd5bd5t6h2lh80j_3r0000gn/T/ipykernel_8058/2046309554.py:15: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /var/folders/5l/znh6jbkd5bd5t6h2lh80j_3r0000gn/T/ipykernel_8058/2046309554.py:15: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /var/folders/5l/znh6jbkd5bd5t6h2lh80j_3r0000gn/T/ipykernel_8058/2046309554.py:15: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /var/folders/5l/znh6jbkd5bd5t6h2lh80j_3r0000gn/T/ipykernel_8058/2046309554.py:15: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /var/folders/5l/znh6jbkd5bd5t6h2lh80j_3r0000gn/T/ipykernel_8058/2046309554.py:15: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /var/folders/5l/znh6jbkd5bd5t6h2lh80j_3r0000gn/T/ipykernel_8058/2046309554.py:15: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
